# %% [markdown]
# # 2D 합성곱(2D Convolutions)

# %% [markdown]
# 2D 합성곱 연산: 앞서 합성곱 신경망을 설명하면서 언급한 이미지 처리에서의 합성곱 연산

# %% [markdown]
# # 1D 합성곱(1D Convolutions)

# %% [markdown]
# 1D 합성곱 연산의 입력: 각 단어가 임베딩 벡터로 변환된 문장 행렬(LSTM의 입려과 동일)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <합성곱 층>
# 1. 합성곱 연산
# - 커널의 크기: 커널의 높이(커널의 너비는 문장 행렬에서의 임베딩 벡터의 차원과 동일)
# - 커널의 이동 방향: 위에서 아래로
# ![image.png](attachment:image.png)
#
# 2. 활성화 함수
#
# <풀링 층>
# 1. 맥스 풀링
# ![image.png](attachment:image-2.png)

# %% [markdown]
# # 신경망 설계하기

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 1. 1D CNN
# - 커널: 크기가 4인 커널 2개, 3인 커널 2개, 2인 커널 2개
# - 맥스 풀링
# - 연결(concatenate)
#
# 2. Fully-Connected layer(Dense layer)
# - 뉴런이 2개인 출력층에 완전 연결
# - 이진 분류여도 소프트맥스(활성화 함수) 사용
