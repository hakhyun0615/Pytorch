# %% [markdown]
# # 다중 클래스 분류(Multi-class Classification)

# %% [markdown]
# 이진 분류의 가설에서 사용되는 활성화 함수가 sigmoid였다면
# 다중 클래스 분류의 가설에서 사용되는 활성화 함수는 softmax 함수입니다.

# %% [markdown]
# ![image.png](attachment:image.png)
